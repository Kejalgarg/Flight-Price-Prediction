# %%
import numpy as np
import pandas as pd
df=pd.read_csv(r'/Users/kejalgarg/Desktop/Research Paper/flight_dataset.csv')
df
# Out:
#            Airline    Source Destination  Total_Stops  Price  Date  Month  \
# 0           IndiGo  Banglore   New Delhi            0   3897    24      3
# 1        Air India   Kolkata    Banglore            2   7662     1      5
# 2      Jet Airways     Delhi      Cochin            2  13882     9      6
# 3           IndiGo   Kolkata    Banglore            1   6218    12      5
# 4           IndiGo  Banglore   New Delhi            1  13302     1      3
# ...            ...       ...         ...          ...    ...   ...    ...
# 10678     Air Asia   Kolkata    Banglore            0   4107     9      4
# 10679    Air India   Kolkata    Banglore            0   4145    27      4
# 10680  Jet Airways  Banglore       Delhi            0   7229    27      4
# 10681      Vistara  Banglore   New Delhi            0  12648     1      3
# 10682    Air India     Delhi      Cochin            2  11753     9      5
#
#        Year  Dep_hours  Dep_min  Arrival_hours  Arrival_min  Duration_hours  \
# 0      2019         22       20              1           10               2
# 1      2019          5       50             13           15               7
# 2      2019          9       25              4           25              19
# 3      2019         18        5             23           30               5
# 4      2019         16       50             21           35               4
# ...     ...        ...      ...            ...          ...             ...
# 10678  2019         19       55             22           25               2
# 10679  2019         20       45             23           20               2
# 10680  2019          8       20             11           20               3
# 10681  2019         11       30             14           10               2
# 10682  2019         10       55             19           15               8
#
#        Duration_min
# 0                50
# 1                25
# 2                 0
# 3                25
# 4                45
# ...             ...
# 10678            30
# 10679            35
# 10680             0
# 10681            40
# 10682            20
#
# [10683 rows x 14 columns]

# %%
df['Total_departure_minutes'] = df['Dep_hours']*60 + df['Dep_min']
df
# Out:
#            Airline    Source Destination  Total_Stops  Price  Date  Month  \
# 0           IndiGo  Banglore   New Delhi            0   3897    24      3
# 1        Air India   Kolkata    Banglore            2   7662     1      5
# 2      Jet Airways     Delhi      Cochin            2  13882     9      6
# 3           IndiGo   Kolkata    Banglore            1   6218    12      5
# 4           IndiGo  Banglore   New Delhi            1  13302     1      3
# ...            ...       ...         ...          ...    ...   ...    ...
# 10678     Air Asia   Kolkata    Banglore            0   4107     9      4
# 10679    Air India   Kolkata    Banglore            0   4145    27      4
# 10680  Jet Airways  Banglore       Delhi            0   7229    27      4
# 10681      Vistara  Banglore   New Delhi            0  12648     1      3
# 10682    Air India     Delhi      Cochin            2  11753     9      5
#
#        Year  Dep_hours  Dep_min  Arrival_hours  Arrival_min  Duration_hours  \
# 0      2019         22       20              1           10               2
# 1      2019          5       50             13           15               7
# 2      2019          9       25              4           25              19
# 3      2019         18        5             23           30               5
# 4      2019         16       50             21           35               4
# ...     ...        ...      ...            ...          ...             ...
# 10678  2019         19       55             22           25               2
# 10679  2019         20       45             23           20               2
# 10680  2019          8       20             11           20               3
# 10681  2019         11       30             14           10               2
# 10682  2019         10       55             19           15               8
#
#        Duration_min  Total_departure_minutes
# 0                50                     1340
# 1                25                      350
# 2                 0                      565
# 3                25                     1085
# 4                45                     1010
# ...             ...                      ...
# 10678            30                     1195
# 10679            35                     1245
# 10680             0                      500
# 10681            40                      690
# 10682            20                      655
#
# [10683 rows x 15 columns]

# %%
df.Airline.value_counts()
# Out:
# Airline
# Jet Airways                          3849
# IndiGo                               2053
# Air India                            1752
# Multiple carriers                    1196
# SpiceJet                              818
# Vistara                               479
# Air Asia                              319
# GoAir                                 194
# Multiple carriers Premium economy      13
# Jet Airways Business                    6
# Vistara Premium economy                 3
# Trujet                                  1
# Name: count, dtype: int64

# %%
df.Source.value_counts()
# Out:
# Source
# Delhi       4537
# Kolkata     2871
# Banglore    2197
# Mumbai       697
# Chennai      381
# Name: count, dtype: int64

# %%
df.Destination.value_counts()
# Out:
# Destination
# Cochin       4537
# Banglore     2871
# Delhi        1265
# New Delhi     932
# Hyderabad     697
# Kolkata       381
# Name: count, dtype: int64

# %%
df.Total_departure_minutes.value_counts()
# Out:
# Total_departure_minutes
# 1135    233
# 1020    227
# 425     205
# 600     203
# 430     202
#        ...
# 985       1
# 95        1
# 1295      1
# 255       1
# 180       1
# Name: count, Length: 222, dtype: int64

# %%
df['Total_Arrival_Minutes']=df['Arrival_hours']*60 +df['Arrival_min']
df
# Out:
#            Airline    Source Destination  Total_Stops  Price  Date  Month  \
# 0           IndiGo  Banglore   New Delhi            0   3897    24      3
# 1        Air India   Kolkata    Banglore            2   7662     1      5
# 2      Jet Airways     Delhi      Cochin            2  13882     9      6
# 3           IndiGo   Kolkata    Banglore            1   6218    12      5
# 4           IndiGo  Banglore   New Delhi            1  13302     1      3
# ...            ...       ...         ...          ...    ...   ...    ...
# 10678     Air Asia   Kolkata    Banglore            0   4107     9      4
# 10679    Air India   Kolkata    Banglore            0   4145    27      4
# 10680  Jet Airways  Banglore       Delhi            0   7229    27      4
# 10681      Vistara  Banglore   New Delhi            0  12648     1      3
# 10682    Air India     Delhi      Cochin            2  11753     9      5
#
#        Year  Dep_hours  Dep_min  Arrival_hours  Arrival_min  Duration_hours  \
# 0      2019         22       20              1           10               2
# 1      2019          5       50             13           15               7
# 2      2019          9       25              4           25              19
# 3      2019         18        5             23           30               5
# 4      2019         16       50             21           35               4
# ...     ...        ...      ...            ...          ...             ...
# 10678  2019         19       55             22           25               2
# 10679  2019         20       45             23           20               2
# 10680  2019          8       20             11           20               3
# 10681  2019         11       30             14           10               2
# 10682  2019         10       55             19           15               8
#
#        Duration_min  Total_departure_minutes  Total_Arrival_Minutes
# 0                50                     1340                     70
# 1                25                      350                    795
# 2                 0                      565                    265
# 3                25                     1085                   1410
# 4                45                     1010                   1295
# ...             ...                      ...                    ...
# 10678            30                     1195                   1345
# 10679            35                     1245                   1400
# 10680             0                      500                    680
# 10681            40                      690                    850
# 10682            20                      655                   1155
#
# [10683 rows x 16 columns]

# %%
df.Total_Arrival_Minutes.value_counts()
# Out:
# Total_Arrival_Minutes
# 1140    618
# 265     589
# 1155    573
# 755     444
# 1260    360
#        ...
# 790       1
# 675       1
# 220       1
# 960       1
# 695       1
# Name: count, Length: 223, dtype: int64

# %%
df['Total_Duration_Minutes']=df['Duration_hours']*60 +df['Duration_min']
df
# Out:
#            Airline    Source Destination  Total_Stops  Price  Date  Month  \
# 0           IndiGo  Banglore   New Delhi            0   3897    24      3
# 1        Air India   Kolkata    Banglore            2   7662     1      5
# 2      Jet Airways     Delhi      Cochin            2  13882     9      6
# 3           IndiGo   Kolkata    Banglore            1   6218    12      5
# 4           IndiGo  Banglore   New Delhi            1  13302     1      3
# ...            ...       ...         ...          ...    ...   ...    ...
# 10678     Air Asia   Kolkata    Banglore            0   4107     9      4
# 10679    Air India   Kolkata    Banglore            0   4145    27      4
# 10680  Jet Airways  Banglore       Delhi            0   7229    27      4
# 10681      Vistara  Banglore   New Delhi            0  12648     1      3
# 10682    Air India     Delhi      Cochin            2  11753     9      5
#
#        Year  Dep_hours  Dep_min  Arrival_hours  Arrival_min  Duration_hours  \
# 0      2019         22       20              1           10               2
# 1      2019          5       50             13           15               7
# 2      2019          9       25              4           25              19
# 3      2019         18        5             23           30               5
# 4      2019         16       50             21           35               4
# ...     ...        ...      ...            ...          ...             ...
# 10678  2019         19       55             22           25               2
# 10679  2019         20       45             23           20               2
# 10680  2019          8       20             11           20               3
# 10681  2019         11       30             14           10               2
# 10682  2019         10       55             19           15               8
#
#        Duration_min  Total_departure_minutes  Total_Arrival_Minutes  \
# 0                50                     1340                     70
# 1                25                      350                    795
# 2                 0                      565                    265
# 3                25                     1085                   1410
# 4                45                     1010                   1295
# ...             ...                      ...                    ...
# 10678            30                     1195                   1345
# 10679            35                     1245                   1400
# 10680             0                      500                    680
# 10681            40                      690                    850
# 10682            20                      655                   1155
#
#        Total_Duration_Minutes
# 0                         170
# 1                         445
# 2                        1140
# 3                         325
# 4                         285
# ...                       ...
# 10678                     150
# 10679                     155
# 10680                     180
# 10681                     160
# 10682                     500
#
# [10683 rows x 17 columns]

# %%
df.Total_Duration_Minutes.value_counts()
# Out:
# Total_Duration_Minutes
# 170     550
# 90      386
# 175     337
# 165     337
# 155     329
#        ...
# 1710      1
# 1675      1
# 2820      1
# 1815      1
# 2860      1
# Name: count, Length: 367, dtype: int64

# %%
df.Total_Stops.value_counts()
# Out:
# Total_Stops
# 1    5626
# 0    3491
# 2    1520
# 3      45
# 4       1
# Name: count, dtype: int64

# %%
df.Date.value_counts()
# Out:
# Date
# 9     1406
# 6     1288
# 27    1130
# 21    1111
# 1     1075
# 24    1052
# 15     984
# 12     957
# 3      848
# 18     832
# Name: count, dtype: int64

# %%
df.Month.value_counts()
# Out:
# Month
# 5    3466
# 6    3414
# 3    2724
# 4    1079
# Name: count, dtype: int64

# %%
df.Year.value_counts()
# Out:
# Year
# 2019    10683
# Name: count, dtype: int64

# %%
df['Total_Duration_Minutes'].min()
# Out:
# 75

# %%
df['Total_Duration_Minutes'].max()
# Out:
# 2860

# %%
df['Total_Duration_Minutes'].median()
# Out:
# 520.0

# %% [markdown]
# ## PREPROCESSING

# %%
df
# Out:
#            Airline    Source Destination  Total_Stops  Price  Date  Month  \
# 0           IndiGo  Banglore   New Delhi            0   3897    24      3
# 1        Air India   Kolkata    Banglore            2   7662     1      5
# 2      Jet Airways     Delhi      Cochin            2  13882     9      6
# 3           IndiGo   Kolkata    Banglore            1   6218    12      5
# 4           IndiGo  Banglore   New Delhi            1  13302     1      3
# ...            ...       ...         ...          ...    ...   ...    ...
# 10678     Air Asia   Kolkata    Banglore            0   4107     9      4
# 10679    Air India   Kolkata    Banglore            0   4145    27      4
# 10680  Jet Airways  Banglore       Delhi            0   7229    27      4
# 10681      Vistara  Banglore   New Delhi            0  12648     1      3
# 10682    Air India     Delhi      Cochin            2  11753     9      5
#
#        Year  Dep_hours  Dep_min  Arrival_hours  Arrival_min  Duration_hours  \
# 0      2019         22       20              1           10               2
# 1      2019          5       50             13           15               7
# 2      2019          9       25              4           25              19
# 3      2019         18        5             23           30               5
# 4      2019         16       50             21           35               4
# ...     ...        ...      ...            ...          ...             ...
# 10678  2019         19       55             22           25               2
# 10679  2019         20       45             23           20               2
# 10680  2019          8       20             11           20               3
# 10681  2019         11       30             14           10               2
# 10682  2019         10       55             19           15               8
#
#        Duration_min  Total_departure_minutes  Total_Arrival_Minutes  \
# 0                50                     1340                     70
# 1                25                      350                    795
# 2                 0                      565                    265
# 3                25                     1085                   1410
# 4                45                     1010                   1295
# ...             ...                      ...                    ...
# 10678            30                     1195                   1345
# 10679            35                     1245                   1400
# 10680             0                      500                    680
# 10681            40                      690                    850
# 10682            20                      655                   1155
#
#        Total_Duration_Minutes
# 0                         170
# 1                         445
# 2                        1140
# 3                         325
# 4                         285
# ...                       ...
# 10678                     150
# 10679                     155
# 10680                     180
# 10681                     160
# 10682                     500
#
# [10683 rows x 17 columns]

# %%
# Define a function to categorize the time of day
def categorize_time(hour):
    if 5 <= hour < 8:
        return 'Early Morning'
    elif 8 <= hour < 12:
        return 'Morning'
    elif 12 <= hour < 16:
        return 'Afternoon'
    elif 16 <= hour < 20:
        return 'Evening'
    else:
        return 'Night'

# Apply the function to Arrival_hours and Dep_hours columns
df['Arrival_Time_Period'] = df['Arrival_hours'].apply(categorize_time)
df['Dep_Time_Period'] = df['Dep_hours'].apply(categorize_time)

# Drop the original hours columns if you no longer need them
df.drop(['Arrival_hours', 'Dep_hours'], axis=1, inplace=True)

df
# Out:
#            Airline    Source Destination  Total_Stops  Price  Date  Month  \
# 0           IndiGo  Banglore   New Delhi            0   3897    24      3
# 1        Air India   Kolkata    Banglore            2   7662     1      5
# 2      Jet Airways     Delhi      Cochin            2  13882     9      6
# 3           IndiGo   Kolkata    Banglore            1   6218    12      5
# 4           IndiGo  Banglore   New Delhi            1  13302     1      3
# ...            ...       ...         ...          ...    ...   ...    ...
# 10678     Air Asia   Kolkata    Banglore            0   4107     9      4
# 10679    Air India   Kolkata    Banglore            0   4145    27      4
# 10680  Jet Airways  Banglore       Delhi            0   7229    27      4
# 10681      Vistara  Banglore   New Delhi            0  12648     1      3
# 10682    Air India     Delhi      Cochin            2  11753     9      5
#
#        Year  Dep_min  Arrival_min  Duration_hours  Duration_min  \
# 0      2019       20           10               2            50
# 1      2019       50           15               7            25
# 2      2019       25           25              19             0
# 3      2019        5           30               5            25
# 4      2019       50           35               4            45
# ...     ...      ...          ...             ...           ...
# 10678  2019       55           25               2            30
# 10679  2019       45           20               2            35
# 10680  2019       20           20               3             0
# 10681  2019       30           10               2            40
# 10682  2019       55           15               8            20
#
#        Total_departure_minutes  Total_Arrival_Minutes  Total_Duration_Minutes  \
# 0                         1340                     70                     170
# 1                          350                    795                     445
# 2                          565                    265                    1140
# 3                         1085                   1410                     325
# 4                         1010                   1295                     285
# ...                        ...                    ...                     ...
# 10678                     1195                   1345                     150
# 10679                     1245                   1400                     155
# 10680                      500                    680                     180
# 10681                      690                    850                     160
# 10682                      655                   1155                     500
#
#       Arrival_Time_Period Dep_Time_Period
# 0                   Night           Night
# 1               Afternoon   Early Morning
# 2                   Night         Morning
# 3                   Night         Evening
# 4                   Night         Evening
# ...                   ...             ...
# 10678               Night         Evening
# 10679               Night           Night
# 10680             Morning         Morning
# 10681           Afternoon         Morning
# 10682             Evening         Morning
#
# [10683 rows x 17 columns]

# %%
df.drop(['Dep_min', 'Arrival_min','Duration_hours', 'Duration_min'], axis=1, inplace=True)
df
# Out:
#            Airline    Source Destination  Total_Stops  Price  Date  Month  \
# 0           IndiGo  Banglore   New Delhi            0   3897    24      3
# 1        Air India   Kolkata    Banglore            2   7662     1      5
# 2      Jet Airways     Delhi      Cochin            2  13882     9      6
# 3           IndiGo   Kolkata    Banglore            1   6218    12      5
# 4           IndiGo  Banglore   New Delhi            1  13302     1      3
# ...            ...       ...         ...          ...    ...   ...    ...
# 10678     Air Asia   Kolkata    Banglore            0   4107     9      4
# 10679    Air India   Kolkata    Banglore            0   4145    27      4
# 10680  Jet Airways  Banglore       Delhi            0   7229    27      4
# 10681      Vistara  Banglore   New Delhi            0  12648     1      3
# 10682    Air India     Delhi      Cochin            2  11753     9      5
#
#        Year  Total_departure_minutes  Total_Arrival_Minutes  \
# 0      2019                     1340                     70
# 1      2019                      350                    795
# 2      2019                      565                    265
# 3      2019                     1085                   1410
# 4      2019                     1010                   1295
# ...     ...                      ...                    ...
# 10678  2019                     1195                   1345
# 10679  2019                     1245                   1400
# 10680  2019                      500                    680
# 10681  2019                      690                    850
# 10682  2019                      655                   1155
#
#        Total_Duration_Minutes Arrival_Time_Period Dep_Time_Period
# 0                         170               Night           Night
# 1                         445           Afternoon   Early Morning
# 2                        1140               Night         Morning
# 3                         325               Night         Evening
# 4                         285               Night         Evening
# ...                       ...                 ...             ...
# 10678                     150               Night         Evening
# 10679                     155               Night           Night
# 10680                     180             Morning         Morning
# 10681                     160           Afternoon         Morning
# 10682                     500             Evening         Morning
#
# [10683 rows x 13 columns]

# %%
df.Total_Stops = pd.factorize(df.Total_Stops)[0]

# %%
df=df.join(pd.get_dummies(df.Airline, prefix='Airline')).drop('Airline', axis=1)

# %%
df=df.join(pd.get_dummies(df.Source, prefix='From')).drop('Source', axis=1)
df=df.join(pd.get_dummies(df.Destination, prefix='To')).drop('Destination', axis=1)
df=df.join(pd.get_dummies(df.Arrival_Time_Period, prefix='Arrival')).drop('Arrival_Time_Period', axis=1)
df=df.join(pd.get_dummies(df.Dep_Time_Period, prefix='Departure')).drop('Dep_Time_Period', axis=1)

# %%
df = df.astype(int)

# %%
df
# Out:
#        Total_Stops  Price  Date  Month  Year  Total_departure_minutes  \
# 0                0   3897    24      3  2019                     1340
# 1                1   7662     1      5  2019                      350
# 2                1  13882     9      6  2019                      565
# 3                2   6218    12      5  2019                     1085
# 4                2  13302     1      3  2019                     1010
# ...            ...    ...   ...    ...   ...                      ...
# 10678            0   4107     9      4  2019                     1195
# 10679            0   4145    27      4  2019                     1245
# 10680            0   7229    27      4  2019                      500
# 10681            0  12648     1      3  2019                      690
# 10682            1  11753     9      5  2019                      655
#
#        Total_Arrival_Minutes  Total_Duration_Minutes  Airline_Air Asia  \
# 0                         70                     170                 0
# 1                        795                     445                 0
# 2                        265                    1140                 0
# 3                       1410                     325                 0
# 4                       1295                     285                 0
# ...                      ...                     ...               ...
# 10678                   1345                     150                 1
# 10679                   1400                     155                 0
# 10680                    680                     180                 0
# 10681                    850                     160                 0
# 10682                   1155                     500                 0
#
#        Airline_Air India  ...  Arrival_Afternoon  Arrival_Early Morning  \
# 0                      0  ...                  0                      0
# 1                      1  ...                  1                      0
# 2                      0  ...                  0                      0
# 3                      0  ...                  0                      0
# 4                      0  ...                  0                      0
# ...                  ...  ...                ...                    ...
# 10678                  0  ...                  0                      0
# 10679                  1  ...                  0                      0
# 10680                  0  ...                  0                      0
# 10681                  0  ...                  1                      0
# 10682                  1  ...                  0                      0
#
#        Arrival_Evening  Arrival_Morning  Arrival_Night  Departure_Afternoon  \
# 0                    0                0              1                    0
# 1                    0                0              0                    0
# 2                    0                0              1                    0
# 3                    0                0              1                    0
# 4                    0                0              1                    0
# ...                ...              ...            ...                  ...
# 10678                0                0              1                    0
# 10679                0                0              1                    0
# 10680                0                1              0                    0
# 10681                0                0              0                    0
# 10682                1                0              0                    0
#
#        Departure_Early Morning  Departure_Evening  Departure_Morning  \
# 0                            0                  0                  0
# 1                            1                  0                  0
# 2                            0                  0                  1
# 3                            0                  1                  0
# 4                            0                  1                  0
# ...                        ...                ...                ...
# 10678                        0                  1                  0
# 10679                        0                  0                  0
# 10680                        0                  0                  1
# 10681                        0                  0                  1
# 10682                        0                  0                  1
#
#        Departure_Night
# 0                    1
# 1                    0
# 2                    0
# 3                    0
# 4                    0
# ...                ...
# 10678                0
# 10679                1
# 10680                0
# 10681                0
# 10682                0
#
# [10683 rows x 41 columns]

# %% [markdown]
# ## TRAINING

# %%
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestRegressor
x,y = df.drop('Price',axis=1), df.Price

# %%
x_train, x_test, y_train, y_test = train_test_split (x,y,test_size=0.2)

# %%
reg = RandomForestRegressor(n_jobs=-1)
reg.fit(x_train, y_train)
# Out:
# RandomForestRegressor(n_jobs=-1)

# %%
reg.score(x_test, y_test)
# Out:
# 0.7960847699602566

# %%
import math
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score

y_pred = reg.predict(x_test)

print('R2:' , r2_score(y_test,y_pred))
print('MAE:' , mean_absolute_error(y_test,y_pred))
print('MSE:' , mean_squared_error(y_test,y_pred))
print('RMSE:' , math.sqrt(mean_squared_error(y_test,y_pred)))
# Out:
# R2: 0.7960847699602566
# MAE: 1251.1282685528738
# MSE: 4339196.961876028
# RMSE: 2083.073921366217

# %%
import matplotlib.pyplot as plt

plt.scatter(y_test,y_pred)
plt.xlabel('Actual Flight Price')
plt.ylabel('Predicted Flight Price')
plt.title('Prediction VS Actual Price')
# Out:
# Text(0.5, 1.0, 'Prediction VS Actual Price')

# %%
df.Price.describe()
# Out:
# count    10683.000000
# mean      9087.064121
# std       4611.359167
# min       1759.000000
# 25%       5277.000000
# 50%       8372.000000
# 75%      12373.000000
# max      79512.000000
# Name: Price, dtype: float64

# %%
importances = dict(zip(reg.feature_names_in_,reg.feature_importances_))
sorted_importances = sorted(importances.items(), key = lambda x:x[1], reverse=True)

sorted_importances
# Out:
# [('Total_Duration_Minutes', 0.4781262693851413),
#  ('Date', 0.14242417564990453),
#  ('Airline_Jet Airways', 0.057723976807203814),
#  ('Airline_Jet Airways Business', 0.05216393284966096),
#  ('Month', 0.051833765834726805),
#  ('Total_Arrival_Minutes', 0.04461678830630193),
#  ('Total_departure_minutes', 0.0346907575773277),
#  ('Total_Stops', 0.026834389170704468),
#  ('To_New Delhi', 0.018347086919889007),
#  ('Airline_Multiple carriers', 0.016390980519755575),
#  ('Airline_IndiGo', 0.009995280453723667),
#  ('From_Banglore', 0.007525687541508376),
#  ('Airline_Air India', 0.005448214790438014),
#  ('From_Mumbai', 0.0042218535597002334),
#  ('To_Hyderabad', 0.0037756863044099485),
#  ('Departure_Morning', 0.0034423393240807947),
#  ('Arrival_Evening', 0.0033613954627715868),
#  ('Departure_Evening', 0.0031527309413878647),
#  ('Departure_Afternoon', 0.0030036318472247392),
#  ('Airline_SpiceJet', 0.0029740294036627517),
#  ('Departure_Night', 0.002835545563014555),
#  ('Arrival_Night', 0.002663888364627647),
#  ('From_Kolkata', 0.002644276711904737),
#  ('Arrival_Afternoon', 0.002401309198706702),
#  ('Arrival_Morning', 0.002338847526681232),
#  ('To_Banglore', 0.002286592986664878),
#  ('Airline_GoAir', 0.002207915076625592),
#  ('From_Delhi', 0.0020068280262755043),
#  ('To_Cochin', 0.0019547063778987297),
#  ('Arrival_Early Morning', 0.00172476352255335),
#  ('Airline_Vistara', 0.0016741117066493985),
#  ('Departure_Early Morning', 0.0016709631151475806),
#  ('Airline_Air Asia', 0.001135034737175717),
#  ('Airline_Multiple carriers Premium economy', 0.0007347787650057668),
#  ('To_Kolkata', 0.0006700469348116872),
#  ('From_Chennai', 0.0005918358269869222),
#  ('To_Delhi', 0.00030710337322557987),
#  ('Airline_Trujet', 5.460411541732957e-05),
#  ('Airline_Vistara Premium economy', 4.387542110296879e-05),
#  ('Year', 0.0)]

# %%
plt.figure(figsize=(10,6))
plt.bar([x[0] for x in sorted_importances[:10]],[x[1] for x in sorted_importances[:10]])
# Out:
# <BarContainer object of 10 artists>

# %%
'''from sklearn.model_selection import GridSearchCV
reg = RandomForestRegresssor(n_jobs=-1)
param_grid= {
    'n_estimators': [100, 200, 300],
    'max_depth': [None, 10, 20, 30],
    'min_samples_split': [2, 5, 10],
    'min_samples_leaf': [1, 2, 4],
    'max_features': ['auto', 'sqrt']
}
grid_search = GridSearchCV(reg, param_grid, cv=5)
grid_search.fit(x_train, y_train)
best_params= grid_search.best_params_'''
# Out:
# "from sklearn.model_selection import GridSearchCV\nreg = RandomForestRegresssor(n_jobs=-1)\nparam_grid= {\n    'n_estimators': [100, 200, 300],\n    'max_depth': [None, 10, 20, 30],\n    'min_samples_split': [2, 5, 10],\n    'min_samples_leaf': [1, 2, 4],\n    'max_features': ['auto', 'sqrt']\n}\ngrid_search = GridSearchCV(reg, param_grid, cv=5)\ngrid_search.fit(x_train, y_train)\nbest_params= grid_search.best_params_"

# %%
from sklearn.model_selection import RandomizedSearchCV
from scipy.stats import randint
param_dist = {
    'n_estimators': randint(100, 300),
    'max_depth': [None, 10, 20, 30, 40, 50],
    'min_samples_split': randint(2,11),
    'min_samples_leaf': randint(2,5),
    'max_features': ['auto', 'sqrt']
}
reg = RandomForestRegressor(n_jobs=-1)
random_search = RandomizedSearchCV(estimator=reg, param_distributions=param_dist, n_iter=2, cv=3,
                                 scoring='neg_mean_squared_error', verbose=2, random_state=10, n_jobs=-1)
random_search.fit(x_train, y_train)
best_regressor = random_search.best_estimator_
# Out:
# Fitting 3 folds for each of 2 candidates, totalling 6 fits
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/ensemble/_forest.py:413: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0` or remove this parameter as it is also the default value for RandomForestRegressors and ExtraTreesRegressors.
#   warn(
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/ensemble/_forest.py:413: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0` or remove this parameter as it is also the default value for RandomForestRegressors and ExtraTreesRegressors.
#   warn(
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/ensemble/_forest.py:413: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0` or remove this parameter as it is also the default value for RandomForestRegressors and ExtraTreesRegressors.
#   warn(
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/ensemble/_forest.py:413: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0` or remove this parameter as it is also the default value for RandomForestRegressors and ExtraTreesRegressors.
#   warn(

# %%
best_regressor.score(x_test, y_test)
# Out:
# 0.7943233075036854

# %%
import math
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score

y_pred = best_regressor.predict(x_test)

print('R2:' , r2_score(y_test,y_pred))
print('MAE:' , mean_absolute_error(y_test,y_pred))
print('MSE:' , mean_squared_error(y_test,y_pred))
print('RMSE:' , math.sqrt(mean_squared_error(y_test,y_pred)))
# Out:
# R2: 0.7943233075036854
# MAE: 1220.8350580087333
# MSE: 4376679.853852868
# RMSE: 2092.0515896728903

# %%
import matplotlib.pyplot as plt

plt.scatter(y_test,y_pred)
plt.xlabel('Actual Flight Price')
plt.ylabel('Predicted Flight Price')
plt.title('Prediction VS Actual Price')
# Out:
# Text(0.5, 1.0, 'Prediction VS Actual Price')
